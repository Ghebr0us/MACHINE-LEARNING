# %% [markdown]
# # Verifica

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/breast-cancer-wisconsin.data', names = ['id',	'Clump Thickness',	'Uniformity of Cell Size',	'Uniformity of Cell Shape',	'Marginal Adhesion',	'Single Epithelial Cell Size',	'Bare Nuclei',	'Bland Chromatin',	'Normal Nucleoli',	'Mitoses',	'Class'])

# %%
df #NOTA: IPOTIZZARE CHE LE COLONNE SIANO RINOMINATE COME INSERITO NEL BLOCCO DI CODICE PRECEDENTE, PER QUESTIONI DI TEMPO NON HO POTUTO RINOMINARLE
# Out:
#           id  Clump Thickness  Uniformity of Cell Size  \
# 0    1000025                5                        1
# 1    1002945                5                        4
# 2    1015425                3                        1
# 3    1016277                6                        8
# 4    1017023                4                        1
# ..       ...              ...                      ...
# 694   776715                3                        1
# 695   841769                2                        1
# 696   888820                5                       10
# 697   897471                4                        8
# 698   897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           1                  1                            2
# 1                           4                  5                            7
# ...

# %%
#2.1 eliminare dal dataset le colonne o i dati inutili se presenti
df = df.drop('id', axis=1)
#2.2 modificare, se necessario, i dati presenti per poter utilizzare senza problemi i metodi oggetto della verifica
#sempre facendo riferimento alla nota delle colonne
df["Bare Nuclei"]=pd.to_numeric(df["Bare Nuclei"], errors='coerce')
df
# Out:
#      Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0                  5                        1                         1
# 1                  5                        4                         4
# 2                  3                        1                         1
# 3                  6                        8                         8
# 4                  4                        1                         1
# ..               ...                      ...                       ...
# 694                3                        1                         1
# 695                2                        1                         1
# 696                5                       10                        10
# 697                4                        8                         6
# 698                4                        8                         8
#
#      Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# ...

# %%
df=df.dropna().reset_index(drop=True)

# %%
df
# Out:
#      Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0                  5                        1                         1
# 1                  5                        4                         4
# 2                  3                        1                         1
# 3                  6                        8                         8
# 4                  4                        1                         1
# ..               ...                      ...                       ...
# 678                3                        1                         1
# 679                2                        1                         1
# 680                5                       10                        10
# 681                4                        8                         6
# 682                4                        8                         8
#
#      Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# ...

# %% [markdown]
# # non so a cosa serva sistemare dopo titolo

# %%
print(x[:10])
print(f'y = {y[:10]}')
# Out:
# [[  20.57       17.77      132.9      1326.          0.08474     0.07864
#      0.0869      0.07017     0.1812      0.05667     0.5435      0.7339
#      3.398      74.08        0.005225    0.01308     0.0186      0.0134
#      0.01389     0.003532   24.99       23.41      158.8      1956.
#      0.1238      0.1866      0.2416      0.186       0.275       0.08902 ]
#  [  19.69       21.25      130.       1203.          0.1096      0.1599
#      0.1974      0.1279      0.2069      0.05999     0.7456      0.7869
#      4.585      94.03        0.00615     0.04006     0.03832     0.02058
#      0.0225      0.004571   23.57       25.53      152.5      1709.
#      0.1444      0.4245      0.4504      0.243       0.3613      0.08758 ]
#  [  11.42       20.38       77.58      386.1         0.1425      0.2839
#      0.2414      0.1052      0.2597      0.09744     0.4956      1.156
#      3.445      27.23        0.00911     0.07458     0.05661     0.01867
# ...

# %%
np.set_printoptions(suppress=True)
print(x[:10])
print(f'y = {y[:10]}')
# Out:
# [[  20.57       17.77      132.9      1326.          0.08474     0.07864
#      0.0869      0.07017     0.1812      0.05667     0.5435      0.7339
#      3.398      74.08        0.005225    0.01308     0.0186      0.0134
#      0.01389     0.003532   24.99       23.41      158.8      1956.
#      0.1238      0.1866      0.2416      0.186       0.275       0.08902 ]
#  [  19.69       21.25      130.       1203.          0.1096      0.1599
#      0.1974      0.1279      0.2069      0.05999     0.7456      0.7869
#      4.585      94.03        0.00615     0.04006     0.03832     0.02058
#      0.0225      0.004571   23.57       25.53      152.5      1709.
#      0.1444      0.4245      0.4504      0.243       0.3613      0.08758 ]
#  [  11.42       20.38       77.58      386.1         0.1425      0.2839
#      0.2414      0.1052      0.2597      0.09744     0.4956      1.156
#      3.445      27.23        0.00911     0.07458     0.05661     0.01867
# ...

# %% [markdown]
# # 2.3 provare a utilizzare l'algoritmo K-NN  per classificare i dati cercando il valore di K che massimizza l'accuratezza.

# %%
print(df.groupby('Class').size())
# Out:
# Class
# 2    444
# 4    239
# dtype: int64

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt


sns.countplot(x="Class", data=df)
plt.title("Cancer")
plt.xlabel("Type")
plt.ylabel("Counts")
plt.show()

# %%
import numpy as np
dfnp = df.to_numpy()
x=dfnp[:,:-1] # prendiamo tutti i dati tranne l'ultima colonna -> variabili indipendenti, osservazioni
y=dfnp[:,-1] # prendiamo solo l'ultima colonna -> variabile dipendente, target

#Print class frequencies through collections counter
import collections
collections.Counter(y)
# Out:
# Counter({2.0: 444, 4.0: 239})

# %%
print(x[:10])
print(f'y = {y[:10]}')
# Out:
# [[ 5.  1.  1.  1.  2.  1.  3.  1.  1.]
#  [ 5.  4.  4.  5.  7. 10.  3.  2.  1.]
#  [ 3.  1.  1.  1.  2.  2.  3.  1.  1.]
#  [ 6.  8.  8.  1.  3.  4.  3.  7.  1.]
#  [ 4.  1.  1.  3.  2.  1.  3.  1.  1.]
#  [ 8. 10. 10.  8.  7. 10.  9.  7.  1.]
#  [ 1.  1.  1.  1.  2. 10.  3.  1.  1.]
#  [ 2.  1.  2.  1.  2.  1.  3.  1.  1.]
#  [ 2.  1.  1.  1.  2.  1.  1.  1.  5.]
#  [ 4.  2.  1.  1.  2.  1.  2.  1.  1.]]
# y = [2. 2. 2. 2. 2. 4. 2. 2. 2. 2.]

# %%
#2.3. provare a utilizzare l'algoritmo K-NN  per classificare i dati cercando il valore di K che massimizza l'accuratezza. 
# !pip install sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#Prima di tutti, trovo il miglior n_neighbors per avere una accuratezza migliore con l'algoritmo
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
best_accuracy = 0
best_n_neighbors = 0

for n_neighbors in range(1, 21):
    # Dividi il dataset in training e test set
    X_train, X_test, y_train, y_test = train_test_split(x, y, 
                                                    test_size = 0.33, # by default is 75%-25%
                                                    # shuffle is set True by default,
                                                    stratify = y, # per mantenere le proporzioni che ci sono nei dati di partenza
                                                    random_state = 123)
    # Crea e addestra il modello KNN
    neigh = KNeighborsClassifier(n_neighbors=n_neighbors)
    neigh.fit(X_train, y_train)

    # Fai la predizione sul test set
    predict = neigh.predict(X_test)

    # Calcola l'accuracy del modello
    report = classification_report(y_test, predict, output_dict=True)
    accuracy = round(report['accuracy']*100)

    # Verifica se l'accuracy del modello è la migliore finora
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_n_neighbors = n_neighbors

# Stampa il valore migliore di n_neighbors e l'accuracy corrispondente
print("Il valore migliore di n_neighbors è", best_n_neighbors, "con un'accuracy del", best_accuracy, "%")
# Out:
# Il valore migliore di n_neighbors è 1 con un'accuracy del 97 %

# %%
from sklearn.model_selection import train_test_split # suddivide le osservazioni nei due insiemi

X_train, X_test, y_train, y_test = train_test_split(x, y, 
                                                    test_size = 0.33, # by default is 75%-25%
                                                    # shuffle is set True by default,
                                                    stratify = y, # per mantenere le proporzioni che ci sono nei dati di partenza
                                                    random_state = 123)

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((380, 30), (380,), (188, 30), (188,))

# %%
from sklearn.neighbors import KNeighborsClassifier

neigh = KNeighborsClassifier(n_neighbors=14)

neigh.fit(X_train, y_train)

predict = neigh.predict(X_test)
print(f'dati predetti dal metodo =                {predict[:10]}') # dati predetti dal metodo
print(f'dati reali presenti nel dataset di test = {y_test[:10]}')
# Out:
# dati predetti dal metodo =                [1. 2. 2. 2. 2. 2. 2. 2. 1. 2.]
# dati reali presenti nel dataset di test = [1. 2. 2. 2. 2. 2. 2. 2. 2. 2.]

# %%
# !pip install tabulate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df
# Out:
#      M  17.99  10.38   122.8    1001   0.1184   0.2776   0.3001   0.1471  \
# 0    1  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690  0.07017
# 1    1  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740  0.12790
# 2    1  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140  0.10520
# 3    1  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800  0.10430
# 4    1  12.45  15.70   82.57   477.1  0.12780  0.17000  0.15780  0.08089
# ..  ..    ...    ...     ...     ...      ...      ...      ...      ...
# 563  1  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390  0.13890
# 564  1  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400  0.09791
# 565  1  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251  0.05302
# 566  1  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140  0.15200
# 567  2   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000  0.00000
#
#      0.2419  ...   25.38  17.33   184.6    2019   0.1622   0.6656  0.7119  \
# ...

# %%
#2.4 utilizzare il metodo per ipotizzare la classe di appartenenza della persona che ha queste caratteristiche:
from tabulate import tabulate

info = ['17.99', '10.38', '122.8', '1001', '0.1184', '0.2776','0.3001','0.1471','0.2419']
daScoprire = [10,10,10,10,5,10,10,10,7] 
print(tabulate([daScoprire], headers=info))
daScoprire = [[10,10,10,10,5,10,10,10,7]]
predictVino = neigh.predict(daScoprire)
predictVino
# Out:
#   17.99    10.38    122.8    1001    0.1184    0.2776    0.3001    0.1471    0.2419
# -------  -------  -------  ------  --------  --------  --------  --------  --------
#      10       10       10      10         5        10        10        10         7
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-161-eb61f4329261> in <module>
#       5 print(tabulate([daScoprire], headers=info))
#       6 daScoprire = [[10,10,10,10,5,10,10,10,7]]
# ----> 7 predictVino = neigh.predict(daScoprire)
#       8 predictVino
#
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     232             # In that case, we do not need the distances to perform
#     233             # the weighting so we do not compute them.
# --> 234             neigh_ind = self.kneighbors(X, return_distance=False)
#     235             neigh_dist = None
# ...

# %%
#2.5 provare a utilizzare l'algoritmo decision tree con diversi valori dei parametri del metodo per classificare i dati. Inserire nel notebook le varie prove effettuate spiegando quali sono i valori dei parametri che meglio descrivono il fenomeno e perché

from sklearn import tree

# impostiamo i parametri del metodo
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
tree_clf = tree.DecisionTreeClassifier(criterion="gini", # criteri per stabilire come splittare
                                       max_depth=4, # profondità dell'albero per evitare l'overfitting
                                       min_samples_split=30, # dimensione minima del sottogruppo a cui fermarsi (no more split)
                                       max_leaf_nodes=6, # numero dei nodi foglia
                                       min_samples_leaf=4 # numero di campioni per essere una foglia
                                      )

# prima parte: dobbiamo fare in modo che il metodo impari dalle informazioni a disposizione
tree_clf.fit(X_train,y_train)

# seconda parte: vediamo se il metodo ha imparato bene facendogli prevedere i risultati 
predict = tree_clf.predict(X_test)

# visualizziamo il risultato (solo i primi dieci pazienti)
print(f'dati predetti dal metodo =                {predict[:10]}') # dati predetti dal metodo
print(f'dati reali presenti nel dataset di test = {y_test[:10]}') # dati effettivi presenti nel test set
# Out:
# dati predetti dal metodo =                [1. 1. 2. 2. 2. 2. 2. 2. 2. 2.]
# dati reali presenti nel dataset di test = [1. 2. 2. 2. 2. 2. 2. 2. 2. 2.]

# %%
#IL GRAFICO
features=list(df.columns.values)

import graphviz
dot_data = tree.export_graphviz(tree_clf, out_file=None, 
                     feature_names=features[1:],  
                     class_names=['0','1'],  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)
graph.render('cancer')
graph
#Questo grafico con questi valori rappresenta la struttura effettiva di come viene effettuato il calcolo e la classificazione della classe(1,2) si basa su una prima condizione per poi andare nello specifico con i successivi valori realativi, NOTA: sempre facendo riferimento a la nota in capo alla pagina
#dove viene specificata la modifica alle colonne

# %%
#2.7 fare un confronto tra i due metodi e dire quale è il migliore a seconda delle richieste facendo un confronto tra le due confusion matrix e i classification report
from mlxtend.plotting import plot_confusion_matrix
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

plot_confusion_matrix(confusion_matrix(y_test, predict), cmap=plt.cm.Dark2)
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

neigh = KNeighborsClassifier(n_neighbors=14)

neigh.fit(X_train, y_train)

predict = neigh.predict(X_test)

# %%
from mlxtend.plotting import plot_confusion_matrix
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

plot_confusion_matrix(confusion_matrix(y_test, predict), cmap=plt.cm.Dark2)
plt.show()

# %%
#2.8 i dati dell'esercizio 2.4 sono presenti nel dataset. Controllare a quale classe appartengono e verificare se i metodi hanno classificato correttamente. I dati appartenevano al training set o al test set?
